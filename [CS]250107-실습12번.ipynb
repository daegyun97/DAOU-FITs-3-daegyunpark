# %% [markdown]
# <a href="https://colab.research.google.com/github/daegyun97/DAOU-FITs-3-daegyunpark/blob/%EC%8B%A4%EC%8A%B5/%5BCS%5D250107-%EC%8B%A4%EC%8A%B512%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 배열 초기화
arr = [1,2,3,4,5,];
arr_zeros = [0]*5;
arr_ones = [1]*5;
print(arr_ones);

# 배열 요소 접근
print(arr[0]);
print(arr[2]);
print(arr[-1]);

# 배열길이 구하기
print(len(arr));
# Out:
# [1, 1, 1, 1, 1]
# 1
# 3
# 5
# 5
