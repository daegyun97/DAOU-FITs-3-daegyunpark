# %% [markdown]
# <a href="https://colab.research.google.com/github/daegyun97/DAOU-FITs-3-daegyunpark/blob/%EC%8B%A4%EC%8A%B5/%5B%EC%8B%A4%EC%8A%B5%5D%5BCS%5D250108-22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  return a+b

def substract(a,b):
  return a-b

# %%
import unittest
from mymodule import add, substract

class TestMathFunctions(unittest.TestCase):
  def test_add(self):
    self.assertEqual(add(1,2),3)

  def test_substract(self):
    self.assertEqual(substract(5,3),2)

  def test_add_negative(self):
    self.assertEqual(add(-1, -2),-3)

  def test_substract_negative(self):
    self.assertEqual(substract(-5,-3), -2)

if __name__== '__main__':
  unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.010s
#
# OK

# %%
# !cd
