# %% [markdown]
# <a href="https://colab.research.google.com/github/daegyun97/DAOU-FITs-3-daegyunpark/blob/%EC%8B%A4%EC%8A%B5/%5B%EC%8B%A4%EC%8A%B5%5D%5BCS%5D250109-25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df.isnull().sum()
# Out:
# customer_id         0
# age                 0
# tenure              0
# balance             0
# num_product         0
# has_credit_card     0
# is_active_member    0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
y = df['churn']
x = df.drop('churn', axis=1)

# %%
# pd.get_dummies(x, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
